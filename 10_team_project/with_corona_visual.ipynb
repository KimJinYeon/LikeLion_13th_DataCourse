# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import pandas as pd
import matplotlib
import platform
import os

# %%
path = "C:/Windows/Fonts/malgun.ttf"
if platform.system() == "Windows":
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
elif platform.system()=="Darwin":
    rc('font', family='AppleGothic')
else:
    print("Unknown System")
    
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
data_merged = pd.read_csv('./data/data_merged(2021-09-28).csv')

# %%
data_merged
# Out:
#          국가 국가코드       확진자        치료중      위중증     사망자          완치 치명(%)  \
# 0        미국   🇺🇸  43942335  9838383.0  21819.0  709119  33394833.0   1.6
# 1        인도   🇮🇳  33714241   289782.0   8944.0  447699  32976760.0   1.3
# 2       브라질   🇧🇷  21366395   410502.0   8318.0  594702  20361191.0   2.8
# 3        영국   🇬🇧   7701715  1346396.0    878.0  136208   6219111.0   1.8
# 4       러시아   🇷🇺   7464708   623692.0   2300.0  205531   6635485.0   2.8
# ..      ...  ...       ...        ...      ...     ...         ...   ...
# 189    몬트세랫   🇲🇸        33        2.0      2.0       1        30.0   3.0
# 190  솔로몬 제도   🇸🇧        20        0.0      2.0       0        20.0     -
# 191     사모아   🇼🇸         3        0.0      2.0       0         3.0     -
# 192  세인트헬레나   🇸🇭         2        0.0      2.0       0         2.0     -
# 193  미크로네시아   🇫🇲         1        0.0      2.0       0         1.0     -
#
#      완치(%)     발생률         인구수 Countries and regions  Doses administered  \
# ...

# %%
data_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   국가                                194 non-null    object
#  1   국가코드                              194 non-null    object
#  2   확진자                               194 non-null    int64
#  3   치료중                               194 non-null    float64
#  4   위중증                               194 non-null    float64
#  5   사망자                               194 non-null    int64
#  6   완치                                194 non-null    float64
#  7   치명(%)                             194 non-null    object
#  8   완치(%)                             194 non-null    float64
#  9   발생률                               194 non-null    int64
#  10  인구수                               194 non-null    int64
# ...

# %%
data_merged.shape
# Out:
# (194, 17)

# %%
data_merged.corr()
# Out:
#                                        확진자       치료중       위중증       사망자  \
# 확진자                               1.000000  0.756921  0.914133  0.932277
# 치료중                               0.756921  1.000000  0.838396  0.677162
# 위중증                               0.914133  0.838396  1.000000  0.890000
# 사망자                               0.932277  0.677162  0.890000  1.000000
# 완치                                0.992527  0.671659  0.878988  0.928230
# 완치(%)                             0.040583 -0.067926  0.008219  0.045056
# 발생률                               0.172492  0.148313  0.110312  0.168690
# 인구수                               0.520326  0.172612  0.414061  0.441678
# Doses administered                0.351743  0.169638  0.285765  0.309391
# Enough for % of people            0.104672  0.076537  0.048241  0.094861
# given 1+ dose                     0.127117  0.075718  0.071913  0.125914
# Daily rate of doses administered  0.649207  0.107595  0.514933  0.611061
#
# ...

# %%
sns.pairplot(data_merged)

# %%
sns.lmplot(x='인구수', y='확진자', data=data_merged)

# %%
sns.lmplot(x='인구수', y='발생률', data=data_merged)

# %%
sns.scatterplot(x='인구수', y='발생률', data=data_merged)
# Out:
# <AxesSubplot:xlabel='인구수', ylabel='발생률'>

# %%
sns.lmplot(x='Doses administered', y='사망자', data=data_merged)

# %%
#is_venezuela = df['country'] == 'Venezuela'
with_corona = data_merged['국가'] in ['미국', '영국', '싱가포르', '스웨덴', '이스라엘']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_6876/703474816.py in <module>
#       1 #is_venezuela = df['country'] == 'Venezuela'
# ----> 2 with_corona = data_merged['국가'] in ['미국', '영국', '싱가포르', '스웨덴', '이스라엘']
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
