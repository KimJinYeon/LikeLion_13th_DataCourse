# %%
import pandas as pd
from datetime import date, timedelta

# %%
corona = pd.read_csv('./data/coronaboard(2021-09-29).csv')
vaccine = pd.read_csv('./data/bloomberg(2021-09-29).csv')
country = pd.read_csv('./data/country.csv')

# %%
jandam = corona.loc[corona['국가'] == '잔담🚢', :]
jandam
# Out:
#       국가  확진자  치료중  위중증  사망자   완치 치명(%)  완치(%) 발생률 인구수
# 215  잔담🚢    9  0.0  NaN    2  7.0  22.2   77.8   -   -

# %%
corona.drop(jandam.index, inplace=True)

# %%
corona['국가']
# Out:
# 0          미국🇺🇸
# 1          인도🇮🇳
# 2         브라질🇧🇷
# 3          영국🇬🇧
# 4         러시아🇷🇺
#          ...
# 217     마셜 제도🇲🇭
# 218      바누아투🇻🇺
# 219       사모아🇼🇸
# 220    세인트헬레나🇸🇭
# 221    미크로네시아🇫🇲
# Name: 국가, Length: 221, dtype: object

# %%
corona['국가코드'] = corona['국가'].str[-2:]

# %%
corona['국가'] = corona['국가'].str[:-2]

# %%
corona.head()
# Out:
#     국가       확진자        치료중      위중증     사망자          완치 치명(%)  완치(%)     발생률  \
# 0   미국  44055692  9823512.0  21296.0  711222  33520958.0   1.6   76.1  133437
# 1   인도  33718984   284976.0   8944.0  447828  32986180.0   1.3   97.8   24448
# 2  브라질  21381790   403027.0   8318.0  595520  20383243.0   2.8   95.3  100676
# 3   영국   7736235  1344510.0    831.0  136375   6255350.0   1.8   80.9  114476
# 4  러시아   7487138   626809.0   2300.0  206388   6653941.0   2.8   88.9   51305
#
#           인구수 국가코드
# 0   331002651   🇺🇸
# 1  1380004385   🇮🇳
# 2   212559417   🇧🇷
# 3    67886011   🇬🇧
# 4   145934462   🇷🇺

# %%
corona.columns
# Out:
# Index(['국가', '확진자', '치료중', '위중증', '사망자', '완치', '치명(%)', '완치(%)', '발생률', '인구수',
#        '국가코드'],
#       dtype='object')

# %%
col = ['국가', '국가코드', '확진자', '치료중', '위중증', '사망자', '완치', '치명(%)', '완치(%)', '발생률', '인구수']

# %%
corona = corona[col].copy()

# %%
corona.head()
# Out:
#     국가 국가코드       확진자        치료중      위중증     사망자          완치 치명(%)  완치(%)  \
# 0   미국   🇺🇸  44055692  9823512.0  21296.0  711222  33520958.0   1.6   76.1
# 1   인도   🇮🇳  33718984   284976.0   8944.0  447828  32986180.0   1.3   97.8
# 2  브라질   🇧🇷  21381790   403027.0   8318.0  595520  20383243.0   2.8   95.3
# 3   영국   🇬🇧   7736235  1344510.0    831.0  136375   6255350.0   1.8   80.9
# 4  러시아   🇷🇺   7487138   626809.0   2300.0  206388   6653941.0   2.8   88.9
#
#       발생률         인구수
# 0  133437   331002651
# 1   24448  1380004385
# 2  100676   212559417
# 3  114476    67886011
# 4   51305   145934462

# %%
corona.tail()
# Out:
#          국가 국가코드  확진자  치료중  위중증  사망자   완치 치명(%)  완치(%)  발생률     인구수
# 217   마셜 제도   🇲🇭    4  0.0  NaN    0  4.0     -  100.0   68   59190
# 218    바누아투   🇻🇺    4  0.0  NaN    1  3.0    25   75.0   13  307145
# 219     사모아   🇼🇸    3  0.0  NaN    0  3.0     -  100.0   15  198414
# 220  세인트헬레나   🇸🇭    2  0.0  NaN    0  2.0     -  100.0  329    6077
# 221  미크로네시아   🇫🇲    1  0.0  NaN    0  1.0     -  100.0    9  115023

# %%
country
# Out:
#     국문(코로나보드)      영문(블룸버그)   나라        비고_뜻
# 0          가나         Ghana  NaN         NaN
# 1          가봉         Gabon  NaN         NaN
# 2        가이아나        Guyana  NaN         NaN
# 3         감비아        Gambia  NaN         NaN
# 4        과들루프           NaN  프랑스  Guadeloupe
# ..        ...           ...  ...         ...
# 222       NaN         Nauru  NaN         나우루
# 223       NaN         Tonga  NaN          통가
# 224       NaN  Turkmenistan  NaN     투르크메니스탄
# 225       NaN        Jersey  NaN          저지
# 226       NaN            EU  NaN         NaN
#
# [227 rows x 4 columns]

# %%
vaccine
# Out:
#     Countries and regions Doses administered Enough for % of people  \
# 0            Global Total         6199443468                      –
# 1          Mainland China         2203185000                   78.7
# 2                   India          876538633                   32.0
# 3                      EU          564029956                   63.5
# 4                    U.S.          391152574                   61.1
# ..                    ...                ...                    ...
# 221                 Nauru              14863                   57.2
# 222            St. Helena               7892                   65.8
# 223      Falkland Islands               4407                   73.5
# 224            Montserrat               2871                   28.7
# 225               Eritrea                  –                      –
#
#     given 1+ dose fully vaccinated Daily rate of doses administered
# 0               –                –                         29152868
# 1            78.6             73.0                          3171286
# 2            46.7             16.8                          7178901
# 3            67.3             64.7                          1052903
# 4            64.4             55.8                           701422
# ..            ...              ...                              ...
# 221          58.6             55.8                                4
# 222          72.7             58.9                                8
# 223          87.7             59.2                              202
# 224          29.7             27.8                                2
# 225             –                –                                –
#
# [226 rows x 6 columns]

# %%
corona = corona.merge(country, left_on='국가', right_on='국문(코로나보드)')

# %%
corona
# Out:
#          국가 국가코드       확진자        치료중      위중증     사망자          완치 치명(%)  \
# 0        미국   🇺🇸  44055692  9823512.0  21296.0  711222  33520958.0   1.6
# 1        인도   🇮🇳  33718984   284976.0   8944.0  447828  32986180.0   1.3
# 2       브라질   🇧🇷  21381790   403027.0   8318.0  595520  20383243.0   2.8
# 3        영국   🇬🇧   7736235  1344510.0    831.0  136375   6255350.0   1.8
# 4       러시아   🇷🇺   7487138   626809.0   2300.0  206388   6653941.0   2.8
# ..      ...  ...       ...        ...      ...     ...         ...   ...
# 214   마셜 제도   🇲🇭         4        0.0      NaN       0         4.0     -
# 215    바누아투   🇻🇺         4        0.0      NaN       1         3.0    25
# 216     사모아   🇼🇸         3        0.0      NaN       0         3.0     -
# 217  세인트헬레나   🇸🇭         2        0.0      NaN       0         2.0     -
# 218  미크로네시아   🇫🇲         1        0.0      NaN       0         1.0     -
#
#      완치(%)     발생률         인구수 국문(코로나보드)    영문(블룸버그)   나라  \
# 0     76.1  133437   331002651        미국        U.S.  NaN
# 1     97.8   24448  1380004385        인도       India  NaN
# 2     95.3  100676   212559417       브라질      Brazil  NaN
# 3     80.9  114476    67886011        영국        U.K.  NaN
# 4     88.9   51305   145934462       러시아      Russia  NaN
# ..     ...     ...         ...       ...         ...  ...
# 214  100.0      68       59190     마셜 제도         NaN  NaN
# 215   75.0      13      307145      바누아투         NaN  NaN
# 216  100.0      15      198414       사모아       Samoa  NaN
# 217  100.0     329        6077    세인트헬레나  St. Helena  NaN
# 218  100.0       9      115023    미크로네시아  Micronesia  NaN
#
#                                  비고_뜻
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 214  Republic of the Marshall Islands
# 215               Republic of Vanuatu
# 216                               NaN
# 217                               NaN
# 218                               NaN
#
# [219 rows x 15 columns]

# %%
corona.drop(['국문(코로나보드)', '나라', '비고_뜻'], axis=1, inplace=True)

# %%
corona
# Out:
#          국가 국가코드       확진자        치료중      위중증     사망자          완치 치명(%)  \
# 0        미국   🇺🇸  44055692  9823512.0  21296.0  711222  33520958.0   1.6
# 1        인도   🇮🇳  33718984   284976.0   8944.0  447828  32986180.0   1.3
# 2       브라질   🇧🇷  21381790   403027.0   8318.0  595520  20383243.0   2.8
# 3        영국   🇬🇧   7736235  1344510.0    831.0  136375   6255350.0   1.8
# 4       러시아   🇷🇺   7487138   626809.0   2300.0  206388   6653941.0   2.8
# ..      ...  ...       ...        ...      ...     ...         ...   ...
# 214   마셜 제도   🇲🇭         4        0.0      NaN       0         4.0     -
# 215    바누아투   🇻🇺         4        0.0      NaN       1         3.0    25
# 216     사모아   🇼🇸         3        0.0      NaN       0         3.0     -
# 217  세인트헬레나   🇸🇭         2        0.0      NaN       0         2.0     -
# 218  미크로네시아   🇫🇲         1        0.0      NaN       0         1.0     -
#
#      완치(%)     발생률         인구수    영문(블룸버그)
# 0     76.1  133437   331002651        U.S.
# 1     97.8   24448  1380004385       India
# 2     95.3  100676   212559417      Brazil
# 3     80.9  114476    67886011        U.K.
# 4     88.9   51305   145934462      Russia
# ..     ...     ...         ...         ...
# 214  100.0      68       59190         NaN
# 215   75.0      13      307145         NaN
# 216  100.0      15      198414       Samoa
# 217  100.0     329        6077  St. Helena
# 218  100.0       9      115023  Micronesia
#
# [219 rows x 12 columns]

# %%
corona = corona.merge(vaccine, left_on='영문(블룸버그)', right_on='Countries and regions')

# %%
corona.drop(['영문(블룸버그)'], axis=1, inplace=True)

# %%
corona
# Out:
#          국가 국가코드       확진자        치료중      위중증     사망자          완치 치명(%)  \
# 0        미국   🇺🇸  44055692  9823512.0  21296.0  711222  33520958.0   1.6
# 1        인도   🇮🇳  33718984   284976.0   8944.0  447828  32986180.0   1.3
# 2       브라질   🇧🇷  21381790   403027.0   8318.0  595520  20383243.0   2.8
# 3        영국   🇬🇧   7736235  1344510.0    831.0  136375   6255350.0   1.8
# 4       러시아   🇷🇺   7487138   626809.0   2300.0  206388   6653941.0   2.8
# ..      ...  ...       ...        ...      ...     ...         ...   ...
# 189    몬트세랫   🇲🇸        33        2.0      NaN       1        30.0   3.0
# 190  솔로몬 제도   🇸🇧        20        0.0      NaN       0        20.0     -
# 191     사모아   🇼🇸         3        0.0      NaN       0         3.0     -
# 192  세인트헬레나   🇸🇭         2        0.0      NaN       0         2.0     -
# 193  미크로네시아   🇫🇲         1        0.0      NaN       0         1.0     -
#
#      완치(%)     발생률         인구수 Countries and regions Doses administered  \
# 0     76.1  133437   331002651                  U.S.          391152574
# 1     97.8   24448  1380004385                 India          876538633
# 2     95.3  100676   212559417                Brazil          233261963
# 3     80.9  114476    67886011                  U.K.           93565474
# 4     88.9   51305   145934462                Russia           89865316
# ..     ...     ...         ...                   ...                ...
# 189   90.9    6611        4992            Montserrat               2871
# 190  100.0      29      686884       Solomon Islands              97744
# 191  100.0      15      198414                 Samoa             149431
# 192  100.0     329        6077            St. Helena               7892
# 193  100.0       9      115023            Micronesia              72085
#
#     Enough for % of people given 1+ dose fully vaccinated  \
# 0                     61.1          64.4             55.8
# 1                     32.0          46.7             16.8
# 2                     56.5          71.3             41.9
# 3                     70.0          73.0             67.1
# 4                     30.6          32.6             28.5
# ..                     ...           ...              ...
# 189                   28.7          29.7             27.8
# 190                    7.6          11.6              3.6
# 191                   37.2          49.3             25.0
# 192                   65.8          72.7             58.9
# 193                   34.7          41.6                –
#
#     Daily rate of doses administered
# 0                             701422
# 1                            7178901
# 2                            1317163
# 3                              63126
# 4                             214966
# ..                               ...
# 189                                2
# 190                             2902
# 191                              981
# 192                                8
# 193                              266
#
# [194 rows x 17 columns]

# %%
corona['위중증'] = corona['위중증'].interpolate()

# %%
corona['치료중'] = corona['치료중'].interpolate()

# %%
corona['완치'] = corona['완치'].interpolate()

# %%
corona['치명(%)'] = corona['치명(%)'].interpolate()

# %%
corona['완치(%)'] = corona['완치(%)'].interpolate()

# %%
corona.isnull().sum()
# Out:
# 국가                                  0
# 국가코드                                0
# 확진자                                 0
# 치료중                                 0
# 위중증                                 0
# 사망자                                 0
# 완치                                  0
# 치명(%)                               0
# 완치(%)                               0
# 발생률                                 0
# 인구수                                 0
# Countries and regions               0
# Doses administered                  0
# Enough for % of people              0
# given 1+ dose                       0
# fully vaccinated                    0
# Daily rate of doses administered    0
# dtype: int64

# %%
# 어제 날짜
yesterday = date.today() - timedelta(1)
yesterday = yesterday.strftime('%Y-%m-%d')

# 파일명 정하기
file_name = f'./data/data_merged({yesterday}).csv'

# %%
corona.to_csv(file_name, index=False, encoding='utf-8-sig')
