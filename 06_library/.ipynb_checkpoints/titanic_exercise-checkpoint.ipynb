# %%
import seaborn as sns

# %%
data = sns.load_dataset("titanic")
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data.fare.describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: fare, dtype: float64

# %%
data.loc[(data['fare'] >= 0 ) & (data['fare'] < 7.9104),'group_fare'] = 1
data.loc[(data['fare'] >= 7.9104) & (data['fare'] < 14.4542),'group_fare'] = 2
data.loc[(data['fare'] >= 14.4542) & (data['fare'] < 31),'group_fare'] = 3
data.loc[(data['fare'] >= 31) & (data['fare'] <= 512.3292),'group_fare'] = 4

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
data_fare1 = data[(data['fare'] >= 0 ) & (data['fare'] < 7.9104)]
data_fare1
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare embarked  class  \
# 0           0       3    male  22.0      1      0  7.2500        S  Third
# 14          0       3  female  14.0      0      0  7.8542        S  Third
# 19          1       3  female   NaN      0      0  7.2250        C  Third
# 26          0       3    male   NaN      0      0  7.2250        C  Third
# 28          1       3  female   NaN      0      0  7.8792        Q  Third
# ..        ...     ...     ...   ...    ...    ...     ...      ...    ...
# 877         0       3    male  19.0      0      0  7.8958        S  Third
# 878         0       3    male   NaN      0      0  7.8958        S  Third
# 881         0       3    male  33.0      0      0  7.8958        S  Third
# 884         0       3    male  25.0      0      0  7.0500        S  Third
# 890         0       3    male  32.0      0      0  7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data_fare2 = data[(data['fare'] >= 7.9104) & (data['fare'] < 14.4542)]
data_fare2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 12          0       3    male  20.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 873         0       3    male  47.0      0      0   9.0000        S   Third
# 876         0       3    male  20.0      0      0   9.8458        S   Third
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 886         0       2    male  27.0      0      0  13.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data_fare3 = data[(data['fare'] >= 14.4542) & (data['fare'] < 31)]
data_fare3
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 11          1       1  female  58.0      0      0  26.5500        S   First
# 15          1       2  female  55.0      0      0  16.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data_fare4 = data[(data['fare'] >= 31) & (data['fare'] <= 512.3292)]
data_fare4
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 1           1       1  female  38.0      1      0   71.2833        C  First
# 3           1       1  female  35.0      1      0   53.1000        S  First
# 6           0       1    male  54.0      0      0   51.8625        S  First
# 13          0       3    male  39.0      1      5   31.2750        S  Third
# 23          1       1    male  28.0      0      0   35.5000        S  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 856         1       1  female  45.0      1      1  164.8667        S  First
# 863         0       3  female   NaN      8      2   69.5500        S  Third
# 867         0       1    male  31.0      0      0   50.4958        S  First
# 871         1       1  female  47.0      1      1   52.5542        S  First
# 879         1       1  female  56.0      0      1   83.1583        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
len(data_fare1) + len(data_fare2) + len(data_fare3) + len(data_fare4)
# Out:
# 891

# %%
sns.histplot(data_fare1['fare'])
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %%
sns.histplot(data_fare2['fare'])
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %%
sns.histplot(data_fare3['fare'])
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %%
sns.histplot(data_fare4['fare'])
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %%
data.age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: age, dtype: float64

# %%
data_age1 = data[(data['age'] >= 0) & (data['age'] < 20.125)]
data_age1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 12          0       3    male  20.0      0      0   8.0500        S   Third
# 14          0       3  female  14.0      0      0   7.8542        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 869         1       3    male   4.0      1      1  11.1333        S   Third
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 876         0       3    male  20.0      0      0   9.8458        S   Third
# 877         0       3    male  19.0      0      0   7.8958        S   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data_age2 = data[(data['age'] >= 20.125) & (data['age'] < 28)]
data_age2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 37          0       3    male  21.0      0      0   8.0500        S   Third
# 41          0       2  female  27.0      1      0  21.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data_age3 = data[(data['age'] >= 28) & (data['age'] < 38)]
data_age3
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 18          0       3  female  31.0      1      0  18.0000        S   Third
# 20          0       2    male  35.0      0      0  26.0000        S  Second
# 21          1       2    male  34.0      0      0  13.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 872         0       1    male  33.0      0      0   5.0000        S   First
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data_age4 = data[(data['age'] >= 38) & (data['age'] <= 80)]
data_age4
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 11          1       1  female  58.0      0      0  26.5500        S   First
# 13          0       3    male  39.0      1      5  31.2750        S   Third
# 15          1       2  female  55.0      0      0  16.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 865         1       2  female  42.0      0      0  13.0000        S  Second
# 871         1       1  female  47.0      1      1  52.5542        S   First
# 873         0       3    male  47.0      0      0   9.0000        S   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
len(data_age1) + len(data_age2) + len(data_age3) + len(data_age4)
# Out:
# 714

# %%
sns.histplot(data_age1['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.histplot(data_age2['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.histplot(data_age3['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.histplot(data_age4['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
data.loc[(data['age'] >= 0) & (data['age'] < 20.125),'group_age'] = 1
data.loc[(data['age'] >= 20.125) & (data['age'] < 28),'group_age'] = 2
data.loc[(data['age'] >= 28) & (data['age'] < 38),'group_age'] = 3
data.loc[(data['age'] >= 38) & (data['age'] <= 80),'group_age'] = 4

grp_age_01 = data[data['group_age'] == 1]
grp_age_02 = data[data['group_age'] == 2]
grp_age_03 = data[data['group_age'] == 3]
grp_age_04 = data[data['group_age'] == 4]

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
sns.histplot(grp_age_01['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.histplot(grp_age_02['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.histplot(grp_age_03['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.histplot(grp_age_04['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
data.groupby(['group_fare']).mean()
# Out:
#             survived    pclass        age     sibsp     parch       fare  \
# group_fare
# 1.0         0.197309  2.919283  28.328671  0.053812  0.022422   7.034172
# 2.0         0.308756  2.603687  29.136186  0.129032  0.092166  10.254819
# 3.0         0.442478  2.265487  28.860939  0.761062  0.610619  22.657281
# 4.0         0.582222  1.462222  32.030204  1.128889  0.786667  87.908834
#
#             adult_male     alone  group_age
# group_fare
# 1.0           0.802691  0.941704   2.363636
# 2.0           0.695853  0.861751   2.484536
# 3.0           0.491150  0.323009   2.535912
# 4.0           0.426667  0.297778   2.729592

# %%
data.groupby(['group_fare']).sum()
# Out:
#             survived  pclass      age  sibsp  parch        fare  adult_male  \
# group_fare
# 1.0               44     651  4051.00     12      5   1568.6203         179
# 2.0               67     565  5652.42     28     20   2225.2958         151
# 3.0              100     512  5223.83    172    138   5120.5456         111
# 4.0              131     329  6277.92    254    177  19779.4876          96
#
#             alone  group_age
# group_fare
# 1.0           210      338.0
# 2.0           187      482.0
# 3.0            73      459.0
# 4.0            67      535.0

# %%
data.groupby(['group_fare']).median()
# Out:
#             survived  pclass   age  sibsp  parch    fare  adult_male  alone  \
# group_fare
# 1.0              0.0     3.0  25.0    0.0    0.0   7.750         1.0    1.0
# 2.0              0.0     3.0  28.0    0.0    0.0   9.825         1.0    1.0
# 3.0              0.0     2.0  29.0    1.0    0.0  24.150         0.0    0.0
# 4.0              1.0     1.0  31.5    1.0    0.0  69.300         0.0    0.0
#
#             group_age
# group_fare
# 1.0               2.0
# 2.0               3.0
# 3.0               3.0
# 4.0               3.0

# %%
data.groupby(['group_fare']).count()
# Out:
#             survived  pclass  sex  age  sibsp  parch  fare  embarked  class  \
# group_fare
# 1.0              223     223  223  143    223    223   223       223    223
# 2.0              217     217  217  194    217    217   217       217    217
# 3.0              226     226  226  181    226    226   226       226    226
# 4.0              225     225  225  196    225    225   225       223    225
#
#             who  adult_male  deck  embark_town  alive  alone  group_age
# group_fare
# 1.0         223         223     8          223    223    223        143
# 2.0         217         217    16          217    217    217        194
# 3.0         226         226    40          226    226    226        181
# 4.0         225         225   139          223    225    225        196

# %%
sel = ['pclass', 'sex', 'age', 'fare', 'group_fare']
data[sel].groupby(['group_fare']).count()
# Out:
#             pclass  sex  age  fare
# group_fare
# 1.0            223  223  143   223
# 2.0            217  217  194   217
# 3.0            226  226  181   226
# 4.0            225  225  196   225
