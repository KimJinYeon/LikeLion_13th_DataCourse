# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import pandas as pd
import matplotlib
import platform
import os

# %%
path = "C:/Windows/Fonts/malgun.ttf"
if platform.system() == "Windows":
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
elif platform.system()=="Darwin":
    rc('font', family='AppleGothic')
else:
    print("Unknown System")
    
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.groupby(['Pclass', 'Survived', 'Sex']).count()
# Out:
#                         PassengerId  Name  Age  SibSp  Parch  Ticket  Fare  \
# Pclass Survived Sex
# 1      0        female            3     3    3      3      3       3     3
#                 male             77    77   61     77     77      77    77
#        1        female           91    91   82     91     91      91    91
#                 male             45    45   40     45     45      45    45
# 2      0        female            6     6    6      6      6       6     6
#                 male             91    91   84     91     91      91    91
#        1        female           70    70   68     70     70      70    70
#                 male             17    17   15     17     17      17    17
# 3      0        female           72    72   55     72     72      72    72
#                 male            300   300  215    300    300     300   300
#        1        female           72    72   47     72     72      72    72
# ...

# %%
train.loc[(train['Pclass'] == 1) & (train['Survived'] == 0), : ].count()
# Out:
# PassengerId    80
# Survived       80
# Pclass         80
# Name           80
# Sex            80
# Age            64
# SibSp          80
# Parch          80
# Ticket         80
# Fare           80
# Cabin          59
# Embarked       80
# dtype: int64

# %%
train.loc[(train['Pclass'] == 1) & (train['Survived'] == 1), : ]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 23            24         1       1
# 31            32         1       1
# ..           ...       ...     ...
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
train.describe(include=['O'])
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
train.groupby(['Pclass']).Survived.count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Survived, dtype: int64

# %%
train.groupby(['SibSp']).Age.mean()
# Out:
# SibSp
# 0    31.397558
# 1    30.089727
# 2    22.620000
# 3    13.916667
# 4     7.055556
# 5    10.200000
# 8          NaN
# Name: Age, dtype: float64

# %%
train.groupby(['SibSp']).mean()
# Out:
#        PassengerId  Survived    Pclass        Age     Parch       Fare
# SibSp
# 0       455.370066  0.345395  2.351974  31.397558  0.185855  25.692028
# 1       439.727273  0.535885  2.057416  30.089727  0.655502  44.147370
# 2       412.428571  0.464286  2.357143  22.620000  0.642857  51.753718
# 3       321.562500  0.250000  2.562500  13.916667  1.312500  68.908862
# 4       381.611111  0.166667  3.000000   7.055556  1.500000  31.855556
# 5       336.800000  0.000000  3.000000  10.200000  2.000000  46.900000
# 8       481.714286  0.000000  3.000000        NaN  2.000000  69.550000

# %%
train.groupby(['Pclass', 'Sex', 'Embarked']).count()
# Out:
#                         PassengerId  Survived  Name  Age  SibSp  Parch  \
# Pclass Sex    Embarked
# 1      female C                  43        43    43   38     43     43
#               Q                   1         1     1    1      1      1
#               S                  48        48    48   44     48     48
#        male   C                  42        42    42   36     42     42
#               Q                   1         1     1    1      1      1
#               S                  79        79    79   64     79     79
# 2      female C                   7         7     7    7      7      7
#               Q                   2         2     2    1      2      2
#               S                  67        67    67   66     67     67
#        male   C                  10        10    10    8     10     10
#               Q                   1         1     1    1      1      1
#               S                  97        97    97   90     97     97
# ...

# %%
train[["SibSp", "Age"]].groupby(["SibSp"]).mean()
# Out:
#              Age
# SibSp
# 0      31.397558
# 1      30.089727
# 2      22.620000
# 3      13.916667
# 4       7.055556
# 5      10.200000
# 8            NaN

# %%
data = train.groupby(['Pclass', 'Survived','Sex']).count()
data
# Out:
#                         PassengerId  Name  Age  SibSp  Parch  Ticket  Fare  \
# Pclass Survived Sex
# 1      0        female            3     3    3      3      3       3     3
#                 male             77    77   61     77     77      77    77
#        1        female           91    91   82     91     91      91    91
#                 male             45    45   40     45     45      45    45
# 2      0        female            6     6    6      6      6       6     6
#                 male             91    91   84     91     91      91    91
#        1        female           70    70   68     70     70      70    70
#                 male             17    17   15     17     17      17    17
# 3      0        female           72    72   55     72     72      72    72
#                 male            300   300  215    300    300     300   300
#        1        female           72    72   47     72     72      72    72
# ...

# %%
data.sort_values(by='PassengerId', ascending=False)
# Out:
#                         PassengerId  Name  Age  SibSp  Parch  Ticket  Fare  \
# Pclass Survived Sex
# 3      0        male            300   300  215    300    300     300   300
# 1      1        female           91    91   82     91     91      91    91
# 2      0        male             91    91   84     91     91      91    91
# 1      0        male             77    77   61     77     77      77    77
# 3      0        female           72    72   55     72     72      72    72
#        1        female           72    72   47     72     72      72    72
# 2      1        female           70    70   68     70     70      70    70
# 3      1        male             47    47   38     47     47      47    47
# 1      1        male             45    45   40     45     45      45    45
# 2      1        male             17    17   15     17     17      17    17
#        0        female            6     6    6      6      6       6     6
# ...

# %%
train.drop(['Ticket', 'Cabin'], axis=1, inplace=True)

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train.drop(['Name'], axis=1, inplace=True)

# %%
train
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female   NaN      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# ...

# %%
train.isna().count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Sex            891
# Age            891
# SibSp          891
# Parch          891
# Fare           891
# Embarked       891
# dtype: int64

# %%
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Fare           float64
# Embarked        object
# dtype: object

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# Embarked         2
# dtype: int64

# %%
train.notnull().sum()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Fare           891
# Embarked       889
# dtype: int64

# %%
train.value_counts()
# Out:
# PassengerId  Survived  Pclass  Sex     Age    SibSp  Parch  Fare      Embarked
# 1            0         3       male    22.00  1      0      7.2500    S           1
# 622          1         1       male    42.00  1      0      52.5542   S           1
# 595          0         2       male    37.00  1      0      26.0000   S           1
# 596          0         3       male    36.00  1      1      24.1500   S           1
# 598          0         3       male    49.00  0      0      0.0000    S           1
#                                                                                  ..
# 298          0         1       female  2.00   1      2      151.5500  S           1
# 300          1         1       female  50.00  0      1      247.5208  C           1
# 303          0         3       male    19.00  0      0      0.0000    S           1
# 306          1         1       male    0.92   1      2      151.5500  S           1
# ...

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
num_col = [col for col in train.columns if train[col].dtype in ['int64', 'float64']]

# %%
num_col
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
cat_col = [col for col in train.columns if train[col].dtype in ['O']]

# %%
cat_col
# Out:
# ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %%
train[cat_col]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
train[cat_col].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
train['Sex'] = train['Sex'].map({'female':0, 'male':1}).astype(int)
test['Sex'] = test['Sex'].map({'female':0, 'male':1}).astype(int)

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
train['Embarked'] = train['Embarked'].map({'S':0, 'C':1, 'Q':2}).astype(int)
test['Embarked'] = test['Embarked'].map({'S':0, 'C':1, 'Q':2}).astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_12080/2688568507.py in <module>
# ----> 1 train['Embarked'] = train['Embarked'].map({'S':0, 'C':1, 'Q':2}).astype(int)
#       2 test['Embarked'] = test['Embarked'].map({'S':0, 'C':1, 'Q':2}).astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...
