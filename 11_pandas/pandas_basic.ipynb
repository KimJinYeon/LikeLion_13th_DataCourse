# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import matplotlib
import platform

# %%
path = "C:/Windows/Fonts/malgun.ttf"
if platform.system() == "Windows":
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
elif platform.system()=="Darwin":
    rc('font', family='AppleGothic')
else:
    print("Unknown System")
    
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', '20210921_00_datamerge.csv', 'pandas_basic.ipynb']

# %%
corona = pd.read_csv('20210921_00_datamerge.csv')

# %%
corona
# Out:
#          국가명               eng_code     발생률         인구수    확진자_합계  \
# 0         미국                   U.S.  129632   331002651  42908619
# 1         인도                  India   24277  1380004385  33483170
# 2        브라질                 Brazil   99924   212559417  21239783
# 3         영국                   U.K.  109444    67886011   7429746
# 4        러시아                 Russia   49986   145934462   7294672
# 5        프랑스                 France  106557    65273511   6955333
# 6         터키                 Turkey   81187    84339067   6847259
# 7         이란                   Iran   64794    83992949   5442232
# 8      아르헨티나              Argentina  115923    45195774   5239232
# 9       콜롬비아               Colombia   97107    50882891   4941064
# 10       스페인                  Spain  105434    46754778   4929546
# 11      이탈리아                  Italy   76678    60461826   4636111
# 12     인도네시아              Indonesia   15328   273523615   4192695
# ...

# %%
corona.describe()
# Out:
#                  발생률           인구수        확진자_합계          백신접종     접종률(인구)  \
# count     178.000000  1.780000e+02  1.780000e+02  1.780000e+02  178.000000
# mean    48993.494382  4.249950e+07  1.265176e+06  3.325503e+07   36.968539
# std     48817.275600  1.540749e+08  4.498551e+06  1.766828e+08   27.566173
# min         9.000000  4.992000e+03  1.000000e+00  2.840000e+03    0.100000
# 25%      4628.250000  2.163120e+06  1.908975e+04  3.976682e+05   10.725000
# 50%     36171.500000  9.227860e+06  1.705950e+05  3.083307e+06   33.550000
# 75%     81027.000000  3.076120e+07  6.992360e+05  1.292752e+07   60.425000
# max    212950.000000  1.439324e+09  4.290862e+07  2.174043e+09  116.600000
#
#            발생률_순위      접종률_순위  확진자비율_전체인구        1차접종        2차접종       완치(%)  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  175.000000
# mean    89.500000   89.500000    0.048993   41.005056   20.908427   88.004571
# ...

# %%
corona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   국가명         178 non-null    object
#  1   eng_code    178 non-null    object
#  2   발생률         178 non-null    int64
#  3   인구수         178 non-null    int64
#  4   확진자_합계      178 non-null    int64
#  5   백신접종        178 non-null    float64
#  6   접종률(인구)     178 non-null    float64
#  7   발생률_순위      178 non-null    float64
#  8   접종률_순위      178 non-null    float64
#  9   확진자비율_전체인구  178 non-null    float64
#  10  1차접종        178 non-null    float64
#  11  2차접종        178 non-null    float64
#  12  위중증         131 non-null    object
#  13  치명(%)       178 non-null    object
#  14  완치(%)       175 non-null    float64
#  15  확진자1일       130 non-null    float64
#  16  사망자합계       178 non-null    int64
#  17  사망자1일       104 non-null    float64
#  18  완치합계        175 non-null    float64
# ...

# %%
pd.options.display.max_rows
# Out:
# 500

# %%
pd.options.display.max_columns
# Out:
# 500

# %%
pd.options.display.max_rows = 500
pd.options.display.max_columns = 500

# %%
corona
# Out:
#          국가명               eng_code     발생률         인구수    확진자_합계  \
# 0         미국                   U.S.  129632   331002651  42908619
# 1         인도                  India   24277  1380004385  33483170
# 2        브라질                 Brazil   99924   212559417  21239783
# 3         영국                   U.K.  109444    67886011   7429746
# 4        러시아                 Russia   49986   145934462   7294672
# 5        프랑스                 France  106557    65273511   6955333
# 6         터키                 Turkey   81187    84339067   6847259
# 7         이란                   Iran   64794    83992949   5442232
# 8      아르헨티나              Argentina  115923    45195774   5239232
# 9       콜롬비아               Colombia   97107    50882891   4941064
# 10       스페인                  Spain  105434    46754778   4929546
# 11      이탈리아                  Italy   76678    60461826   4636111
# 12     인도네시아              Indonesia   15328   273523615   4192695
# ...

# %%
corona.columns
# Out:
# Index(['국가명', 'eng_code', '발생률', '인구수', '확진자_합계', '백신접종', '접종률(인구)', '발생률_순위',
#        '접종률_순위', '확진자비율_전체인구', '1차접종', '2차접종', '위중증', '치명(%)', '완치(%)',
#        '확진자1일', '사망자합계', '사망자1일', '완치합계', '완치1일', '접종비율(일간)'],
#       dtype='object')

# %%
corona.columns = ['국가명', 'eng_code', '발생률', '인구수', '확진자_합계', '백신접종', '백신보유율(인구)', '발생률_순위',
       '접종률_순위', '확진자비율_전체인구', '1차접종', '2차접종', '위중증', '치명(%)', '완치(%)',
       '확진자1일', '사망자합계', '사망자1일', '완치합계', '완치1일', '접종비율(일간)']

# %%
corona
# Out:
#          국가명               eng_code     발생률         인구수    확진자_합계  \
# 0         미국                   U.S.  129632   331002651  42908619
# 1         인도                  India   24277  1380004385  33483170
# 2        브라질                 Brazil   99924   212559417  21239783
# 3         영국                   U.K.  109444    67886011   7429746
# 4        러시아                 Russia   49986   145934462   7294672
# 5        프랑스                 France  106557    65273511   6955333
# 6         터키                 Turkey   81187    84339067   6847259
# 7         이란                   Iran   64794    83992949   5442232
# 8      아르헨티나              Argentina  115923    45195774   5239232
# 9       콜롬비아               Colombia   97107    50882891   4941064
# 10       스페인                  Spain  105434    46754778   4929546
# 11      이탈리아                  Italy   76678    60461826   4636111
# 12     인도네시아              Indonesia   15328   273523615   4192695
# ...

# %%
corona.drop(['확진자비율_전체인구'], axis=1, inplace=True)

# %%
corona.columns
# Out:
# Index(['국가명', 'eng_code', '발생률', '인구수', '확진자_합계', '백신접종', '백신보유율(인구)',
#        '발생률_순위', '접종률_순위', '1차접종', '2차접종', '위중증', '치명(%)', '완치(%)', '확진자1일',
#        '사망자합계', '사망자1일', '완치합계', '완치1일', '접종비율(일간)'],
#       dtype='object')

# %%
corona
# Out:
#          국가명               eng_code     발생률         인구수    확진자_합계  \
# 0         미국                   U.S.  129632   331002651  42908619
# 1         인도                  India   24277  1380004385  33483170
# 2        브라질                 Brazil   99924   212559417  21239783
# 3         영국                   U.K.  109444    67886011   7429746
# 4        러시아                 Russia   49986   145934462   7294672
# 5        프랑스                 France  106557    65273511   6955333
# 6         터키                 Turkey   81187    84339067   6847259
# 7         이란                   Iran   64794    83992949   5442232
# 8      아르헨티나              Argentina  115923    45195774   5239232
# 9       콜롬비아               Colombia   97107    50882891   4941064
# 10       스페인                  Spain  105434    46754778   4929546
# 11      이탈리아                  Italy   76678    60461826   4636111
# 12     인도네시아              Indonesia   15328   273523615   4192695
# ...

# %%
corona['인구당확진자비율'] = corona['확진자_합계'] / corona['인구수']
corona.head()
# Out:
#    국가명 eng_code     발생률         인구수    확진자_합계         백신접종  백신보유율(인구)  발생률_순위  \
# 0   미국     U.S.  129632   331002651  42908619  385586020.0       60.2    13.0
# 1   인도    India   24277  1380004385  33483170  808389300.0       29.6   101.0
# 2  브라질   Brazil   99924   212559417  21239783  222322660.0       53.9    27.0
# 3   영국     U.K.  109444    67886011   7429746   93002090.0       69.6    21.0
# 4  러시아   Russia   49986   145934462   7294672   87810616.0       29.9    77.0
#
#    접종률_순위  1차접종  2차접종          위중증 치명(%)  완치(%)    확진자1일   사망자합계  사망자1일  \
# 0    46.0  63.8  54.6  24327\n-523   1.6   75.8  41814.0  691992  430.0
# 1    99.0  43.7  14.5         8944   1.3   97.7  32085.0  445248  349.0
# 2    62.0  69.4  37.8         8318   2.8   95.5   9458.0  590786  239.0
# 3    25.0  72.7  66.5         1020   1.8   80.5  29007.0  135203   56.0
# 4    97.0  31.9  27.6         2300   2.7   89.3  19744.0  198996  778.0
#
#          완치합계     완치1일   접종비율(일간)  인구당확진자비율
# ...

# %%
sns.scatterplot(x='2차접종', y='인구당확진자비율', data=corona)
# Out:
# <AxesSubplot:xlabel='2차접종', ylabel='인구당확진자비율'>

# %%
corona.loc[corona['2차접종']<0,'2차접종']= 0

# %%
sns.scatterplot(x='2차접종', y='인구당확진자비율', data=corona)
# Out:
# <AxesSubplot:xlabel='2차접종', ylabel='인구당확진자비율'>

# %%
sns.lmplot(x='2차접종', y='인구당확진자비율', data=corona)

# %%
sns.scatterplot(x='1차접종', y='인구당확진자비율', data=corona)
# Out:
# <AxesSubplot:xlabel='1차접종', ylabel='인구당확진자비율'>

# %%
sns.lmplot(x='1차접종', y='인구당확진자비율', data=corona)

# %%
sns.scatterplot(x='2차접종', y='발생률', data=corona)
# Out:
# <AxesSubplot:xlabel='2차접종', ylabel='발생률'>

# %%
sns.lmplot(x='2차접종', y='발생률', data=corona)

# %%
sns.scatterplot(x='1차접종', y='발생률', data=corona)
# Out:
# <AxesSubplot:xlabel='1차접종', ylabel='발생률'>

# %%
sns.lmplot(x='1차접종', y='발생률', data=corona)

# %%
corona.corr()
# Out:
#                 발생률       인구수    확진자_합계      백신접종  백신보유율(인구)    발생률_순위  \
# 발생률        1.000000 -0.109224  0.167795 -0.050310   0.582878 -0.938863
# 인구수       -0.109224  1.000000  0.520124  0.902688   0.029238  0.121956
# 확진자_합계     0.167795  0.520124  1.000000  0.340294   0.114367 -0.199806
# 백신접종      -0.050310  0.902688  0.340294  1.000000   0.143130  0.077879
# 백신보유율(인구)  0.582878  0.029238  0.114367  0.143130   1.000000 -0.603678
# 발생률_순위    -0.938863  0.121956 -0.199806  0.077879  -0.603678  1.000000
# 접종률_순위    -0.583907 -0.035454 -0.122922 -0.149285  -0.988947  0.623305
# 1차접종       0.552850  0.044281  0.137810  0.144847   0.981396 -0.582703
# 2차접종       0.584050  0.010485  0.091642  0.132677   0.965266 -0.604454
# 완치(%)      0.238141  0.059054  0.033177  0.051780   0.129941 -0.210499
# 확진자1일      0.138827  0.394490  0.789026  0.249417   0.128753 -0.180332
# 사망자합계      0.165512  0.439190  0.931546  0.298846   0.105382 -0.208175
# ...

# %%
corona['사망률'] = corona['사망자합계'] / corona['인구수']

# %%
corona[['사망률', '2차접종']].corr()
# Out:
#            사망률      2차접종
# 사망률   1.000000  0.349902
# 2차접종  0.349902  1.000000

# %%
sns.lmplot(x='2차접종', y='사망률', data=corona)

# %%
corona[ ['위중증_수', '위중증_증감'] ] =  corona['위중증'].str.split("\n",expand=True)
corona.head()
# Out:
#    국가명 eng_code     발생률         인구수    확진자_합계         백신접종  백신보유율(인구)  발생률_순위  \
# 0   미국     U.S.  129632   331002651  42908619  385586020.0       60.2    13.0
# 1   인도    India   24277  1380004385  33483170  808389300.0       29.6   101.0
# 2  브라질   Brazil   99924   212559417  21239783  222322660.0       53.9    27.0
# 3   영국     U.K.  109444    67886011   7429746   93002090.0       69.6    21.0
# 4  러시아   Russia   49986   145934462   7294672   87810616.0       29.9    77.0
#
#    접종률_순위  1차접종  2차접종          위중증 치명(%)  완치(%)    확진자1일   사망자합계  사망자1일  \
# 0    46.0  63.8  54.6  24327\n-523   1.6   75.8  41814.0  691992  430.0
# 1    99.0  43.7  14.5         8944   1.3   97.7  32085.0  445248  349.0
# 2    62.0  69.4  37.8         8318   2.8   95.5   9458.0  590786  239.0
# 3    25.0  72.7  66.5         1020   1.8   80.5  29007.0  135203   56.0
# 4    97.0  31.9  27.6         2300   2.7   89.3  19744.0  198996  778.0
#
# ...

# %%
corona['위중증_수2'] = corona['위중증_수'].copy()

# %%
corona.loc[ corona['위중증_수2'].isnull(), "위중증_수2"] = -99999
corona[  corona['위중증_수2'].isnull() ]
# Out:
# Empty DataFrame
# Columns: [국가명, eng_code, 발생률, 인구수, 확진자_합계, 백신접종, 백신보유율(인구), 발생률_순위, 접종률_순위, 1차접종, 2차접종, 위중증, 치명(%), 완치(%), 확진자1일, 사망자합계, 사망자1일, 완치합계, 완치1일, 접종비율(일간), 인구당확진자비율, 사망률, 위중증_수, 위중증_증감, 위중증_수2]
# Index: []

# %%
corona['위중증_수2'] = corona['위중증_수2'].astype('int64')

# %%
corona['위중증률'] = corona['위중증_수2'] /  corona['인구수']
corona
# Out:
#          국가명               eng_code     발생률         인구수    확진자_합계  \
# 0         미국                   U.S.  129632   331002651  42908619
# 1         인도                  India   24277  1380004385  33483170
# 2        브라질                 Brazil   99924   212559417  21239783
# 3         영국                   U.K.  109444    67886011   7429746
# 4        러시아                 Russia   49986   145934462   7294672
# 5        프랑스                 France  106557    65273511   6955333
# 6         터키                 Turkey   81187    84339067   6847259
# 7         이란                   Iran   64794    83992949   5442232
# 8      아르헨티나              Argentina  115923    45195774   5239232
# 9       콜롬비아               Colombia   97107    50882891   4941064
# 10       스페인                  Spain  105434    46754778   4929546
# 11      이탈리아                  Italy   76678    60461826   4636111
# 12     인도네시아              Indonesia   15328   273523615   4192695
# ...

# %%
sns.lmplot(x='2차접종', y='위중증률', data=corona)

# %%
sns.lmplot(x='위중증률', y='2차접종', data=corona)

# %%
corona_part = corona.loc[corona['인구수'] >= 2000000, : ]

# %%
corona_part
# Out:
#          국가명               eng_code     발생률         인구수    확진자_합계  \
# 0         미국                   U.S.  129632   331002651  42908619
# 1         인도                  India   24277  1380004385  33483170
# 2        브라질                 Brazil   99924   212559417  21239783
# 3         영국                   U.K.  109444    67886011   7429746
# 4        러시아                 Russia   49986   145934462   7294672
# 5        프랑스                 France  106557    65273511   6955333
# 6         터키                 Turkey   81187    84339067   6847259
# 7         이란                   Iran   64794    83992949   5442232
# 8      아르헨티나              Argentina  115923    45195774   5239232
# 9       콜롬비아               Colombia   97107    50882891   4941064
# 10       스페인                  Spain  105434    46754778   4929546
# 11      이탈리아                  Italy   76678    60461826   4636111
# 12     인도네시아              Indonesia   15328   273523615   4192695
# ...

# %%
corona_part[['2차접종', '인구당확진자비율']].corr()
# Out:
#               2차접종  인구당확진자비율
# 2차접종      1.000000  0.614483
# 인구당확진자비율  0.614483  1.000000

# %%
sns.lmplot(x='2차접종', y='인구당확진자비율', data=corona_part)

# %%
sns.lmplot(x='인구당확진자비율', y='2차접종', data=corona_part)

# %%
corona_part[['1차접종', '인구당확진자비율']].corr()
# Out:
#             1차접종  인구당확진자비율
# 1차접종      1.0000    0.5941
# 인구당확진자비율  0.5941    1.0000

# %%
sns.lmplot(x='1차접종', y='인구당확진자비율', data=corona_part)

# %%
corona_part[['2차접종', '사망률']].corr()
# Out:
#           2차접종       사망률
# 2차접종  1.000000  0.400923
# 사망률   0.400923  1.000000

# %%
sns.lmplot(x='2차접종', y='사망률', data=corona_part)

# %%
corona_part[['1차접종', '사망률']].corr()
# Out:
#          1차접종      사망률
# 1차접종  1.00000  0.38791
# 사망률   0.38791  1.00000

# %%
sns.lmplot(x='1차접종', y='사망률', data=corona_part)

# %%
corona_part[['1차접종', '위중증률']].corr()
# Out:
#           1차접종      위중증률
# 1차접종  1.000000  0.203297
# 위중증률  0.203297  1.000000

# %%
sns.lmplot(x='1차접종', y='위중증률', data=corona_part)

# %%
sns.lmplot(x='위중증률', y='1차접종', data=corona_part)

# %%
corona_part['위중증률']
# Out:
# 0      7.349488e-05
# 1      6.481139e-06
# 2      3.913259e-05
# 3      1.502519e-05
# 4      1.576050e-05
# 5      2.806652e-05
# 6      7.505419e-06
# 7      7.985194e-05
# 8      3.310044e-05
# 9      1.065191e-05
# 10     2.198706e-05
# 11     8.765862e-06
# 12    -3.655955e-04
# 13     1.452546e-05
# 14     3.721320e-05
# 15     2.985736e-06
# 16     2.892835e-05
# 17     4.047216e-06
# 18     3.163304e-05
# 19     3.679788e-05
# 20     1.213899e-05
# 21     1.536454e-05
# 22     2.614628e-06
# 23     1.152784e-05
# 24     2.270326e-05
# 25     1.690418e-05
# 26     8.519068e-06
# 27     6.285102e-05
# 28     8.249057e-05
# 29     2.191113e-05
# 30     1.880993e-05
# 31     4.948619e-05
# 32     4.257736e-06
# 33     8.434094e-06
# 34     2.102379e-05
# 35     2.071561e-05
# 36     1.176990e-05
# 37     3.004175e-05
# 38     4.658216e-06
# 39     4.988663e-05
# 40     4.440867e-05
# 41    -3.432051e-03
# 42    -1.011071e-02
# 43     2.431605e-05
# 44     3.215266e-05
# ...
